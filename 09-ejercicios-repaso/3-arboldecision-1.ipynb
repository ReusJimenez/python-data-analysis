# %% [markdown]
# # Arboles de Decision Parte 1
#
# * ¿Que son los árboles de decisión?
# * Algoritmo ID3
# * Método de selección de atributos
# * Librería Scikit-Learn

# %% [markdown]
# ### ¿Que son los árboles de decisión?

# %% [markdown]
# ![Arboles](https://res.cloudinary.com/vincent1bt/image/upload/q_63/v1539549742/trees_u97cuz.jpg)

# %% [markdown]
# ![TAD](https://i.ytimg.com/vi/HLHb1YZteMg/maxresdefault.jpg)

# %% [markdown]
# ### Algoritmo ID3

# %% [markdown]
# ![Entropia](https://th.bing.com/th/id/R.14f4e3d3ccb6459853f0e4942c0c01c0?rik=T%2fRko0ZDtR1JUg&riu=http%3a%2f%2fwww.bearcave.com%2fmisl%2fmisl_tech%2fwavelets%2fcompression%2fshannon2.jpg&ehk=u8pIml70gQd02QmDmWLAZLc4GA3FQYOFEFu2FATPQHI%3d&risl=&pid=ImgRaw&r=0)

# %%
# Lo más deseado es buscar el árbol más corto.

# %% [markdown]
# ### Método de selección de atributos

# %% [markdown]
# * Atributos: Los atributos son las características o variables que se utilizan para describir cada instancia en el conjunto de datos. Estos atributos pueden ser numéricos, categóricos o binarios, y ayudan al algoritmo a tomar decisiones de clasificación.

# %% [markdown]
# ### Librería Scikit-Learn

# %% [markdown]
# ![Sklearn](https://live.staticflickr.com/65535/48057247952_f9e106cb4a_b.jpg)
