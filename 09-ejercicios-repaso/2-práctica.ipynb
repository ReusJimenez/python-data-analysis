# %% [markdown]
# ### Practica de Pandas
#
# Habrá el archivo "Datos de practica.xlsx" con las tablas de "Ventas" y "Vendedores", y realice las siguientes actividades.
#
# 1. Realice un análisis descriptivo simple para sus variables numericas y categoricas.
# 2. Verifique mediante la creación de columnas nuevas que la columna TOTAL esté bien calculada y en caso contrario corregir los errores.
# 3. Realice la unión de las tablas de la forma más eficiente posible.
# 4. Realice un filtro en donde tenga las ventas del vendedor "Nombre_85 Apellido_85"
# 5. Realice una Tabla resumen en donde evidencie cuanto es el total de ventas por vendedor para los meses de octubre a diciembre.
