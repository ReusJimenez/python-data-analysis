# %% [markdown]
# # **Prueba técnica**
# Dataset y explicacion extraida de: https://youtu.be/anMeXz7lPFE?si=bwq0akv4QnlS44at

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
# Cargar el dataset
df = pd.read_csv("./data/Data Analytics Analyst Assestment.csv")
display(df.head())

# %% [markdown]
# # 1. Limpieza de datos

# %%
# Ver valores nulos
print("Valores nulos por columna:")
print(df.isnull().sum())

# %%
display(df.head())

# %% [markdown]
# # 2. Análisis de Datos Exploratorio (EDA)
