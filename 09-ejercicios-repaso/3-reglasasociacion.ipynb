# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules

# %%
url = (
    "https://raw.githubusercontent.com/JoaquinAmatRodrigo/Estadistica-con-R/"
    "master/datos/datos_groceries.csv"
)
datos = pd.read_csv(url)
datos.head()
# Out:
#    id_compra                 item
# 0          1         citrus fruit
# 1          1  semi-finished bread
# 2          1            margarine
# 3          1          ready soups
# 4          2       tropical fruit

# %%
datos["id_compra"].nunique()
# Out:
# 9835

# %%
datos["item"].nunique()
# Out:
# 169

# %%
datos.shape
# Out:
# (43367, 2)

# %%
# Crear una lista de listas que contenga los ítems de cada transacción
transacciones = datos.groupby("id_compra")["item"].apply(list).to_list()

# Entrenar el objeto TransactionEncoder y transformar los datos
encoder = TransactionEncoder()
transacciones_encoded = encoder.fit(transacciones).transform(transacciones)
transacciones_encoded = pd.DataFrame(transacciones_encoded, columns=encoder.columns_)
transacciones_encoded.head(10)
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
# 5                  False     False              True             False
# 6                  False     False             False             False
# 7                  False      True             False             False
# 8                  False     False             False             False
# 9                  False     False             False             False
#
#    baby cosmetics  baby food   bags  baking powder  bathroom cleaner   beef  \
# 0           False      False  False          False             False  False
# ...

# %%
transacciones_encoded.shape
# Out:
# (9835, 169)

# %%
transacciones
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['pot plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['beef'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetable juice', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
# ...

# %%
transacciones_encoded.head(10)
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
# 5                  False     False              True             False
# 6                  False     False             False             False
# 7                  False      True             False             False
# 8                  False     False             False             False
# 9                  False     False             False             False
#
#    baby cosmetics  baby food   bags  baking powder  bathroom cleaner   beef  \
# 0           False      False  False          False             False  False
# ...

# %%
# Soporte ???

transacciones_encoded.mean(axis = 0).sort_values(ascending = False).head(15)
# Out:
# whole milk          0.255516
# other vegetables    0.193493
# rolls/buns          0.183935
# soda                0.174377
# yogurt              0.139502
# bottled water       0.110524
# root vegetables     0.108998
# tropical fruit      0.104931
# shopping bags       0.098526
# sausage             0.093950
# pastry              0.088968
# citrus fruit        0.082766
# bottled beer        0.080529
# newspapers          0.079817
# canned beer         0.077682
# dtype: float64

# %%
transacciones_encoded.sum(axis = 0).sort_values(ascending = False).head(15)
# Out:
# whole milk          2513
# other vegetables    1903
# rolls/buns          1809
# soda                1715
# yogurt              1372
# bottled water       1087
# root vegetables     1072
# tropical fruit      1032
# shopping bags        969
# sausage              924
# pastry               875
# citrus fruit         814
# bottled beer         792
# newspapers           785
# canned beer          764
# dtype: int64

# %%
transacciones_encoded.shape[0]
# Out:
# 9835

# %%
# Identificación de reglas frecuentes

soporte_min = 30 / transacciones_encoded.shape[0]
print(f"Soporte mínimo: {soporte_min}")
reglas = apriori(transacciones_encoded, min_support = soporte_min, use_colnames = True)
reglas.sort_values(by = "support", ascending = False)
# Out:
# Soporte mínimo: 0.003050330452465684
#        support                                          itemsets
# 133   0.255516                                      (whole milk)
# 83    0.193493                                (other vegetables)
# 98    0.183935                                      (rolls/buns)
# 111   0.174377                                            (soda)
# 134   0.139502                                          (yogurt)
# ...        ...                                               ...
# 1439  0.003050                    (yogurt, butter, citrus fruit)
# 1601  0.003050                  (coffee, yogurt, tropical fruit)
# 664   0.003050                              (dessert, margarine)
# 1884  0.003050                 (whole milk, newspapers, sausage)
# 1366  0.003050  (shopping bags, bottled water, other vegetables)
#
# [2226 rows x 2 columns]

# %%
reglas["n_items"] = reglas["itemsets"].apply(lambda x: len(x))
reglas.query("n_items >= 2").sort_values("support", ascending = False).head(10)
# Out:
#        support                             itemsets  n_items
# 1076  0.074835       (whole milk, other vegetables)        2
# 1171  0.056634             (whole milk, rolls/buns)        2
# 1275  0.056024                 (whole milk, yogurt)        2
# 1185  0.048907        (whole milk, root vegetables)        2
# 1055  0.047382  (other vegetables, root vegetables)        2
# 1077  0.043416           (yogurt, other vegetables)        2
# 1054  0.042603       (other vegetables, rolls/buns)        2
# 1263  0.042298         (whole milk, tropical fruit)        2
# 1240  0.040061                   (whole milk, soda)        2
# 1161  0.038332                   (soda, rolls/buns)        2

# %%
reglas[reglas["n_items"] == 3].sort_values("support", ascending=False)
# Out:
#        support                                         itemsets  n_items
# 1948  0.023183  (whole milk, other vegetables, root vegetables)        3
# 1983  0.022267           (whole milk, yogurt, other vegetables)        3
# 1937  0.017895       (whole milk, other vegetables, rolls/buns)        3
# 1974  0.017082   (whole milk, other vegetables, tropical fruit)        3
# 2068  0.015557                 (whole milk, yogurt, rolls/buns)        3
# ...        ...                                              ...      ...
# 1376  0.003050               (yogurt, bottled water, pip fruit)        3
# 1491  0.003050                        (soda, rolls/buns, candy)        3
# 1379  0.003050       (shopping bags, bottled water, rolls/buns)        3
# 1964  0.003050        (sliced cheese, yogurt, other vegetables)        3
# 1884  0.003050                (whole milk, newspapers, sausage)        3
#
# [850 rows x 3 columns]

# %%
# Buscar las reglas que tengan a "newspapers"

mask = reglas["itemsets"].map(lambda x: "newspapers" in x)
reglas.loc[mask].sort_values(by = "support", ascending = False)
# Out:
#        support                                           itemsets  n_items
# 78    0.079817                                       (newspapers)        1
# 1017  0.027351                           (whole milk, newspapers)        2
# 1006  0.019725                           (newspapers, rolls/buns)        2
# 1002  0.019319                     (newspapers, other vegetables)        2
# 1018  0.015353                               (yogurt, newspapers)        2
# ...        ...                                                ...      ...
# 1876  0.003050                  (newspapers, rolls/buns, sausage)        3
# 1884  0.003050                  (whole milk, newspapers, sausage)        3
# 957   0.003050                                 (meat, newspapers)        2
# 896   0.003050                     (newspapers, hygiene articles)        2
# 2171  0.003050  (whole milk, newspapers, other vegetables, roo...        4
#
# [80 rows x 3 columns]

# %%
# Identificación de itemsets frecuentes

soporte_min_ = 30 / transacciones_encoded.shape[0]
reglas_frecuentes = apriori(transacciones_encoded, min_support = soporte_min_, use_colnames = True)

# Crear reglas de associación (confianza mínima del 70%)

confianza = 0.7 # confianza mínima del 70% para que una regla sea selecionada
reglas_1 = association_rules(reglas_frecuentes, metric = "confidence", min_threshold = confianza)
print(f"Número de reglas generadas: {len(reglas_1)}")
reglas_1.sort_values(by = "support", ascending = False).head(20)
# Out:
# Número de reglas generadas: 19
#                                           antecedents         consequents  \
# 14          (yogurt, root vegetables, tropical fruit)        (whole milk)
# 2                                      (butter, curd)        (whole milk)
# 5                               (domestic eggs, curd)        (whole milk)
# 10    (tropical fruit, root vegetables, citrus fruit)  (other vegetables)
# 15       (yogurt, whipped/sour cream, tropical fruit)        (whole milk)
# 11                     (yogurt, curd, tropical fruit)        (whole milk)
# 4                                      (butter, pork)        (whole milk)
# 18  (yogurt, other vegetables, root vegetables, tr...        (whole milk)
# 6                              (domestic eggs, sugar)        (whole milk)
# 12  (domestic eggs, other vegetables, whipped/sour...        (whole milk)
# 13  (whipped/sour cream, root vegetables, tropical...  (other vegetables)
# ...

# %%
# Seleccionar reglas que tienen "other vegetables" en el consecuente

mask_1 = reglas_1["consequents"].map(lambda x: "other vegetables" in x)
reglas_1.loc[mask_1]
# Out:
#                                           antecedents         consequents  \
# 10    (tropical fruit, root vegetables, citrus fruit)  (other vegetables)
# 13  (whipped/sour cream, root vegetables, tropical...  (other vegetables)
# 16  (whole milk, tropical fruit, root vegetables, ...  (other vegetables)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 10            0.005694            0.193493  0.004474    0.785714  4.060694
# 13            0.004575            0.193493  0.003355    0.733333  3.789981
# 16            0.003559            0.193493  0.003152    0.885714  4.577509
#
#     leverage  conviction  zhangs_metric
# 10  0.003372    3.763701       0.758053
# 13  0.002470    3.024403       0.739530
# 16  0.002463    7.056940       0.784332
