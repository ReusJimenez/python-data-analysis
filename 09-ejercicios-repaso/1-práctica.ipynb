# %%
#1.-Crear una función personalizada que convierta grados centigrados a farenheit

# %%
#2.-Crear una función que devuelva 1 si un número es divisible por 17 y 0 si no lo es

# %%
#3.-Crear una función que devuelva 1 si un número es primo y 0 si no es primo. Para los primeros 20 números

# %%
#4.-Crear una función sume los primeros n números

# %%
#5.-Crea una función que liste los números primos hasta el n
#Para los primeros 20 números
