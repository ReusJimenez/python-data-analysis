# %% [markdown]
# # **Sesión 1 - Fundamentos**

# %%
# Esto es una celda de código, para ejecutar código

# %% [markdown]
# Esto es una **celda de markdown**, para escribir texto

# %%
# print es una función que imprime en pantalla
print('Bienvenido Analista de datos Roberto Eustaquio')
# Out:
# Bienvenido Analista de datos Roberto Eustaquio

# %%
2+2
# Out:
# 4

# %%
#1. Variables
#Son obetos que guardan datos en memoria
#Son dinamicos porque pueden cambiar de valor
peso = 70.50
peso
# Out:
# 70.5

# %%
peso = peso + 1
peso
# Out:
# 71.5

# %%
nombre = "Roberto"
print("Mi nombre es", nombre)
# Out:
# Mi nombre es Roberto

# %%
#2. Los datos tienen tipos
estado = True
estado
# Out:
# True

# %%
type(estado)
# Out:
# bool

# %%
estado = 3
estado
# Out:
# 3

# %%
type(estado)
# Out:
# int

# %% [markdown]
# ## Fórmulas en python

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Crear variables
a = 4
b = 6
c = 2
d = 3
m = (a * b**3) / (b * c**2 - d)

# Mostrar resultados
print("El resultado de la operación es ", m)
# Out:
# El resultado de la operación es  41.142857142857146

# %%
# Definir variables
a = 2
b = 3
c = 4
d = 5
n = (a**5) / (b * c * d) + ((a + b)**3) / (4 * d + c**2)

# Mostrar resultados
print("El resultado de la operación es ", n)
# Out:
# El resultado de la operación es  4.0055555555555555
